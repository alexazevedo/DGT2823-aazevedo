# %% [markdown]
# # Microatividade 1: Ler arquivo CSV

# %%
import pandas as pd

df = pd.read_csv('dados.csv', sep=';', engine='python')
print(df)

# %% [markdown]
# # Microatividade 2: Criar subconjunto de dados

# %%
subconjunto = df[['Duration', 'Pulse', 'Calories']]
print(subconjunto)

# %% [markdown]
# # Microatividade 3: Configurar max_rows e exibir com to_string

# %%
pd.options.display.max_rows = 9999
print(df.to_string())

# %% [markdown]
# # Microatividade 4: Exibir primeiras e últimas 10 linhas

# %%
print(df.head(10))

# %%
print(df.tail(10))

# %% [markdown]
# # Microatividade 5: Exibir informações gerais

# %%
print(df.info())
